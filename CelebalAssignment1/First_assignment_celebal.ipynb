# %% [markdown]
# ## Objective
# Learn Python basics and perform comprehensive data exploration and cleaning on an e-commerce dataset using Pandas.
#
# ### Steps Covered:
# 1. Load CSV dataset into Pandas DataFrame
# 2. Explore data (head/tail, shape, columns, data types)
# 3. Handle missing values (identify, fill/drop)
# 4. Perform basic operations (filter rows, select columns)
# 5. Remove duplicates
# 6. Create derived columns
# 7. Save cleaned dataset as CSV

# %% [markdown]
# # Step 1: Import Libraries

# %%
import pandas as pd
import numpy as np
import warnings as wn
# use this for clean output
wn.filterwarnings("ignore")
print("Libraries are imported successfully")
# Out:
# Libraries are imported successfully

# %% [markdown]
# # Step 2: Load Dataset

# %%
# load csv file into dataframe (df)
df=pd.read_csv("shopping.csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %% [markdown]
# # Step 3: Explore the Dataset

# %% [markdown]
# ### 3.1 Basic Information of Dataset

# %%
print('First 5 rows of the dataset:')
df.head()
# Out:
# First 5 rows of the dataset:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
# ...

# %%
print('Last 5 rows of the dataset:')
df.tail()
# Out:
# Last 5 rows of the dataset:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
print(f"Shape of Dataset:{df.shape}")
print(f"Rows are:{df.shape[0]}")
print(f"Rows are:{df.shape[1]}")
# Out:
# Shape of Dataset:(1000, 24)
# Rows are:1000
# Rows are:24

# %%
print(f"Columns in Dataset:\n\n{list(df.columns)})")
# Out:
# Columns in Dataset:
#
# ['product_id', 'title', 'product_description', 'rating', 'ratings_count', 'initial_price', 'discount', 'final_price', 'currency', 'images', 'delivery_options', 'product_details', 'breadcrumbs', 'product_specifications', 'amount_of_stars', 'what_customers_said', 'seller_name', 'sizes', 'videos', 'seller_information', 'variations', 'best_offer', 'more_offers', 'category'])

# %%
print("Data Types of Dataset:")
pd.DataFrame({"Columns_Names":df.columns,"Data_Types":df.dtypes.values})
# Out:
# Data Types of Dataset:
#              Columns_Names Data_Types
# 0               product_id      int64
# 1                    title     object
# 2      product_description     object
# 3                   rating    float64
# 4            ratings_count      int64
# 5            initial_price      int64
# 6                 discount    float64
# 7              final_price     object
# 8                 currency     object
# 9                   images     object
# 10        delivery_options     object
# 11         product_details     object
# 12             breadcrumbs     object
# 13  product_specifications     object
# 14         amount_of_stars     object
# 15     what_customers_said     object
# 16             seller_name     object
# 17                   sizes     object
# 18                  videos     object
# 19      seller_information     object
# 20              variations     object
# 21              best_offer     object
# 22             more_offers     object
# ...

# %%
print(f"General information of Dataset:\n")
{df.info()}
# Out:
# General information of Dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
# ...

# %% [markdown]
# ### Statistical Summary

# %%
print("Description of Dataset")
df.describe()
# Out:
# Description of Dataset
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %% [markdown]
# # Step:4 Handle Missing Values

# %% [markdown]
# ### 4.1 Identify Missing Values

# %%
missing_values=df.isna().sum()
missing_df=pd.DataFrame({
    "Columns":missing_values.index,
    "Missing_Values_Counts":missing_values.values
})
missing_df=missing_df[missing_df["Missing_Values_Counts"]>0].sort_values("Missing_Values_Counts",ascending=False)
print("Missing values Summary:")
missing_df
# Out:
# Missing values Summary:
#                 Columns  Missing_Values_Counts
# 18               videos                    781
# 15  what_customers_said                    573
# 20           variations                    562
# 16          seller_name                    301
# 19   seller_information                    301
# 6              discount                    121

# %% [markdown]
# ## 4.2 Handling missing values

# %%
# Fill numerical columns with median
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    df[col].fillna(df[col].median(), inplace=True)

# Fill categorical columns with mode
for col in df.select_dtypes(include='object').columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Check remaining missing values
print("Remaining missing values:")
print(df.isnull().sum().sum())
# Out:
# Remaining missing values:
# 0

# %%
# Filter products with high ratings (4.0 and above)
high_rated = df[df['rating'] >= 4.0]
print(f'Products with rating >= 4.0: {len(high_rated)} out of {len(df)}')
# Out:
# Products with rating >= 4.0: 615 out of 1000

# %%
# Filter products with significant discounts (>50%)
high_discount = df[df['discount'] > 50]
print(f'Products with discount > 50%: {len(high_discount)} out of {len(df)}')
# Out:
# Products with discount > 50%: 644 out of 1000

# %% [markdown]
# ### Step6 :Remove Duplicate

# %%
# Check for duplicates
print(f'Total rows before removing duplicates: {len(df)}')
print(f'Duplicate rows based on product_id: {df.duplicated(subset=["product_id"]).sum()}')

# Remove duplicates
df = df.drop_duplicates(subset=['product_id'])
print(f'Total rows after removing duplicates: {len(df)}')
# Out:
# Total rows before removing duplicates: 1000
# Duplicate rows based on product_id: 0
# Total rows after removing duplicates: 1000

# %% [markdown]
# ## Step 7: Create Derived Columns

# %%
# Create a derived column: discount_amount (savings in rupees)
df['discount_amount'] = (df['initial_price'] * df['discount']) / 100

# Create a column: final_price (calculated from initial_price and discount)
df['final_price_calculated'] = df['initial_price'] - df['discount_amount']

# Create a quality score based on rating and number of ratings
df['quality_score'] = (df['rating'] * df['ratings_count']) / df['ratings_count'].max()

# %%
print('\nSample of new columns:')
print(df[['title', 'initial_price', 'discount', 'discount_amount', 'final_price_calculated']].head(10))
# Out:
# Sample of new columns:
#             title  initial_price  discount  discount_amount  \
# 0     Lino Perros           3995      58.0          2317.10
# 1  Tommy Hilfiger           2899      35.0          1014.65
# 2           Lavie           2999      65.0          1949.35
# 3          F Gear           1675      52.0           871.00
# 4       MYTRIDENT           2899      17.0           492.83
# 5             H&M           1399      56.0           783.44
# 6      AVI Living           1399      65.0           909.35
# 7         My Room           2999      54.0          1619.46
# 8         My Room           2999      54.0          1619.46
# 9      Story@home           2199      53.0          1165.47
#
#    final_price_calculated
# 0                 1677.90
# 1                 1884.35
# 2                 1049.65
# 3                  804.00
# 4                 2406.17
# 5                  615.56
# 6                  489.65
# 7                 1379.54
# 8                 1379.54
# ...

# %% [markdown]
# ## Step 8: Final Data Validation

# %%
# Validate data quality
print('Final Data Validation:')
print(f'Total rows: {len(df)}')
print(f'Total columns: {len(df.columns)}')
print(f'Missing values: {df.isnull().sum().sum()}')
print(f'Duplicate rows: {df.duplicated().sum()}')
# Out:
# Final Data Validation:
# Total rows: 1000
# Total columns: 27
# Missing values: 0
# Duplicate rows: 0

# %% [markdown]
# ## Step 9: Save Cleaned Dataset

# %%
output_file = 'Combined_dataset_CLEANED.csv'
df.to_csv(output_file, index=False)
